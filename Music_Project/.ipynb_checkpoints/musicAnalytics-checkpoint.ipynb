# %%
#Imports
import pylast
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Replace with your own API key, secret, and username
API_KEY = "81795854e49b1656fb706caeb7586f05"
API_SECRET = "64318b9880c15ad3fcc48528a55ea9c2"
USERNAME = "qst4"

# Authenticate with pylast
network = pylast.LastFMNetwork(api_key=API_KEY, api_secret=API_SECRET, username=USERNAME)

# %%
#fetch data
# Get top artists for the user
top_artists = network.get_user(USERNAME).get_top_artists(limit=10)

# Print the artist and playcount
for i, artist in enumerate(top_artists, 1):
    print(f"{i}. {artist.item.name} ({artist.weight} plays)")
# Out:
# 1. Earl Klugh (5062 plays)
# 2. Bob James (4217 plays)
# 3. J Dilla (2653 plays)
# 4. Karriem Riggins (2565 plays)
# 5. Vince Guaraldi Trio (1886 plays)
# 6. George Benson (1728 plays)
# 7. Steely Dan (1537 plays)
# 8. Azymuth (1471 plays)
# 9. Paul Desmond (1342 plays)
# 10. Marcos Valle (1331 plays)

# %%
# Fetch a user's top 20 artists (overall)
user = network.get_user(USERNAME)
top_artists_user_overall = user.get_top_artists(limit=20, period="overall")

# Create a list of dictionaries for the DataFrame
artist_data = [
    {
        'Rank': i + 1,
        'Artist': artist.item.name,
        'Playcount': artist.weight,
        'Last.fm URL': artist.item.get_url()
    }
    for i, artist in enumerate(top_artists_user_overall)
]

# Create the DataFrame
df = pd.DataFrame(artist_data)

# Display the DataFrame
df
# Out:
#     Rank               Artist Playcount  \
# 0      1           Earl Klugh      5062
# 1      2            Bob James      4217
# 2      3              J Dilla      2653
# 3      4      Karriem Riggins      2565
# 4      5  Vince Guaraldi Trio      1886
# 5      6        George Benson      1728
# 6      7           Steely Dan      1537
# 7      8              Azymuth      1471
# 8      9         Paul Desmond      1342
# 9     10         Marcos Valle      1331
# 10    11            Gal Costa      1326
# 11    12                 Sade      1290
# 12    13           Spyro Gyra      1271
# 13    14          Elis Regina      1262
# 14    15           Al Jarreau      1256
# 15    16       Howard Roberts      1228
# 16    17       Herbie Hancock      1221
# 17    18                Joyce      1176
# 18    19           Jacob Mann      1150
# 19    20               Madlib      1135
#
#                                           Last.fm URL
# 0              https://www.last.fm/music/earl%2bklugh
# 1               https://www.last.fm/music/bob%2bjames
# 2                 https://www.last.fm/music/j%2bdilla
# 3         https://www.last.fm/music/karriem%2briggins
# 4   https://www.last.fm/music/vince%2bguaraldi%2btrio
# 5           https://www.last.fm/music/george%2bbenson
# 6              https://www.last.fm/music/steely%2bdan
# 7                   https://www.last.fm/music/azymuth
# 8            https://www.last.fm/music/paul%2bdesmond
# 9            https://www.last.fm/music/marcos%2bvalle
# 10              https://www.last.fm/music/gal%2bcosta
# 11                     https://www.last.fm/music/sade
# 12             https://www.last.fm/music/spyro%2bgyra
# 13            https://www.last.fm/music/elis%2bregina
# 14             https://www.last.fm/music/al%2bjarreau
# 15         https://www.last.fm/music/howard%2broberts
# 16         https://www.last.fm/music/herbie%2bhancock
# 17                    https://www.last.fm/music/joyce
# 18             https://www.last.fm/music/jacob%2bmann
# 19                   https://www.last.fm/music/madlib

# %%
print(top_artists_user_overall)
# Out:
# [TopItem(item=pylast.Artist('Earl Klugh', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='5062'), TopItem(item=pylast.Artist('Bob James', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='4217'), TopItem(item=pylast.Artist('J Dilla', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='2653'), TopItem(item=pylast.Artist('Karriem Riggins', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='2565'), TopItem(item=pylast.Artist('Vince Guaraldi Trio', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1886'), TopItem(item=pylast.Artist('George Benson', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1728'), TopItem(item=pylast.Artist('Steely Dan', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1537'), TopItem(item=pylast.Artist('Azymuth', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1471'), TopItem(item=pylast.Artist('Paul Desmond', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1342'), TopItem(item=pylast.Artist('Marcos Valle', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1331'), TopItem(item=pylast.Artist('Gal Costa', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1326'), TopItem(item=pylast.Artist('Sade', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1290'), TopItem(item=pylast.Artist('Spyro Gyra', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1271'), TopItem(item=pylast.Artist('Elis Regina', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1262'), TopItem(item=pylast.Artist('Al Jarreau', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1256'), TopItem(item=pylast.Artist('Howard Roberts', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1228'), TopItem(item=pylast.Artist('Herbie Hancock', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1221'), TopItem(item=pylast.Artist('Joyce', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1176'), TopItem(item=pylast.Artist('Jacob Mann', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1150'), TopItem(item=pylast.Artist('Madlib', pylast.LastFMNetwork('81795854e49b1656fb706caeb7586f05', '64318b9880c15ad3fcc48528a55ea9c2', '', 'qst4', '')), weight='1135')]
